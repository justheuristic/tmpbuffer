# %% [markdown]
# #Чем думает рыба?

# %%
import os
import numpy
def parse(line):
    numbers =line.split(" ")
    return map(int,numbers[:2]), numpy.array(map(float, numbers[2:]))
with open("zebrafish.txt") as fdata:
    sdata = fdata.read().split("\n")[:-1]
    data = map(parse,sdata)

# %%
timeSeries = numpy.array([i[1] for i in data])
timeSeries.shape
# Out:
# (46460, 240)

# %%
from zebrafish_drawing_factory import draw_component

draw_component(timeSeries[:,0])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=[10,10])
for i in range(0,240,10):
    plt.plot(range(240),timeSeries[i])

# %% [markdown]
# #Поищем характерные группы нейронов

# %%
from sklearn.decomposition import PCA
f = PCA()
f.fit(timeSeries)
# Out:
# PCA(copy=True, n_components=None, whiten=False)

# %%
timeSeries_pca = f.transform(timeSeries)

# %% [markdown]
# #посмотрим, где у рыбы какие нейроны

# %%
draw_component(timeSeries_pca[:,0])

# %%
draw_component(timeSeries_pca[:,1])

# %%
draw_component(timeSeries_pca[:,2])

# %%
from zebrafish_drawing_factory import draw_components

draw_components(timeSeries_pca[:,1],timeSeries_pca[:,2])

# %% [markdown]
# #Поищем фичи

# %%
def extract_features(impulses):
    features = []
    
    for i in range (1,10):
        features.append(sum(impulses[1::i]))
    


    return features

# %%
timeSeries_features = numpy.array(map(extract_features, timeSeries))

# %%
timeSeries_features.shape
# Out:
# (46460, 9)

# %%
from sklearn.decomposition import PCA
p = PCA()
p.fit(timeSeries_features)
# Out:
# PCA(copy=True, n_components=None, whiten=False)

# %%
timeSeries_pca = p.transform(timeSeries_features)

# %%
draw_component(timeSeries_pca[:,1])

# %%
draw_component(timeSeries_pca[:,2])

# %%
draw_components(timeSeries_pca[:,1],timeSeries_pca[:,2])

# %%
def extract_features(impulses):

    features = []

    

    for i in range (1,10):

        features.append(sum(impulses[i::10]))


    return features

# %%
timeSeries_featuress = numpy.array(map(extract_features, timeSeries))

# %%
timeSeries_featuress.shape
# Out:
# (46460, 9)

# %%
from sklearn.decomposition import PCA
y = PCA()
y.fit(timeSeries_featuress)
# Out:
# PCA(copy=True, n_components=None, whiten=False)

# %%
timeSeries__pca = y.transform(timeSeries_featuress)

# %%
draw_component(timeSeries__pca[:,1])

# %%
draw_component(timeSeries__pca[:,2])

# %%
draw_components(timeSeries__pca[:,1],timeSeries__pca[:,2])

# %%
def extract_features(impulses):

    features = []
    
    for i in range (1,10):
        for j in range (1,10):
            features.append(sum(impulses[i::10]))


    return features

# %%
timeSeries_featuressS = numpy.array(map(extract_features, timeSeries))

# %%
timeSeries_featuressS.shape

# %%
from sklearn.decomposition import PCA
y = PCA()
y.fit(timeSeries_featuress)

# %%
from sklearn.datasets import load_digits
digits = load_digits(n_class = 10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for image in digits.images[:10]:
    plt.imshow(image, cmap=plt.cm.gray_r,)
    plt.show()

# %%
images = digits.data
Y = digits.target
print images.shape
# Out:
# (1797, 64)

# %%
def extract_features(image):
    features = []
    
    image = image.reshape([8,8])
    
    
    features.append(numpy.sum(image[3:6,3:6]))
    features.append(numpy.sum(image))
    features.append(numpy.sum(image[0:8,0:4]))
    features.append(numpy.sum(image[0:8,4:8]))
    features.append(numpy.sum(image[4:8,0:4]))
    features.append(numpy.sum(image[4:8,0:8]))
    
    
    
    
    
    return features

# %%
import numpy
X = []
for i in range(images.shape[0]):
    X.append(extract_features(images[i]))
X = numpy.array(X)

# %%
print X.shape
# Out:
# (1797, 6)

# %%
from sklearn.cross_validation import train_test_split
Xtrain,Xtest,Ytrain,Ytest = train_test_split(X,Y,train_size = 0.5)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(Xtrain,Ytrain)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')

# %%
Ypred = model.predict(Xtest)

# %%
from sklearn.metrics import accuracy_score
print "test:",accuracy_score(Ypred,Ytest)
# Out:
# test: 0.590656284761

# %%
from sklearn.decomposition import PCA

rbm = PCA()
rbm.fit(Xtrain)
# Out:
# PCA(copy=True, n_components=None, whiten=False)

# %%
X = images

# %%
from sklearn.cross_validation import train_test_split
Xtrain,Xtest,Ytrain,Ytest = train_test_split(X,Y,train_size = 0.5)

# %%
X_t_train = rbm.transform(Xtrain)
X_t_test = rbm.transform(Xtest)
from sklearn.linear_model import LogisticRegression

model = LogisticRegression().fit(X_t_train,Ytrain)

# %%
Ypred = model.predict(X_t_test)

# %%
print "test:",accuracy_score(Ypred,Ytest)
# Out:
# test: 0.949944382647
